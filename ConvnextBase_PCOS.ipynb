# %% [markdown]
# # Data Importing

# %%
#Import The required Python libraries.
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import os
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from skimage import io, transform
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, EarlyStopping,CSVLogger,ProgbarLogger
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D, BatchNormalization
from keras.regularizers import l2

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# **Changable_Parameter**

# %%
#here image size is 256x256
IMAGE_SIZE = 200
#every time process 32 images (61x31)~1951
batch_size = 10
#how many color have in these pictures
CHANNELS = 3
#80x25~1951
EPOCHS = 25
NUM_CLASSES = 2
input_shape = (batch_size, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
patience=5
data_dir ="D:\\Pocs\\pocs"
split_folder = "D:\\Pocs\\split"
model_name="convnext"

# %% [markdown]
# **Directory Creation and split**

# %%
import os
import shutil
import random
import math

# Example paths

train_val_dir = os.path.join(split_folder, "train_validation_data")
test_dir = os.path.join(split_folder, "test_data")

def split_data(source_folder, split_folder, train_val_ratio=0.9):
    # Check if split folders already exist
    if os.path.exists(train_val_dir) and os.path.exists(test_dir):
        print("Split folders already exist. Skipping data split.")
        return
    
    # Create split folders if they do not exist
    if not os.path.exists(split_folder):
        os.makedirs(split_folder)
    if not os.path.exists(train_val_dir):
        os.makedirs(train_val_dir)
    if not os.path.exists(test_dir):
        os.makedirs(test_dir)
    
    # Count variables
    train_val_count = 0
    test_count = 0
    
    # Iterate through source_folder (main folder with classes)
    for class_folder in os.listdir(source_folder):
        class_path = os.path.join(source_folder, class_folder)
        
        if os.path.isdir(class_path):
            # Create corresponding folders in split_folder
            train_val_class_path = os.path.join(train_val_dir, class_folder)
            test_class_path = os.path.join(test_dir, class_folder)
            
            if not os.path.exists(train_val_class_path):
                os.makedirs(train_val_class_path)
            if not os.path.exists(test_class_path):
                os.makedirs(test_class_path)
            
            # List all images in the class folder
            images = [img for img in os.listdir(class_path) if img.endswith('.jpg') or img.endswith('.png')]
            random.shuffle(images)
            
            # Calculate split indices
            split_index = int(len(images) * train_val_ratio)
            
            # Split images into train_validation_data and test_data
            train_val_images = images[:split_index]
            test_images = images[split_index:]
            
            # Copy images to respective split folders
            for img in train_val_images:
                src = os.path.join(class_path, img)
                dst = os.path.join(train_val_class_path, img)
                shutil.copy(src, dst)
                train_val_count += 1
                
            for img in test_images:
                src = os.path.join(class_path, img)
                dst = os.path.join(test_class_path, img)
                shutil.copy(src, dst)
                test_count += 1
    
    print("Data split completed successfully.")
    print(f"Number of images in train_validation_data: {train_val_count}")
    print(f"Number of images in test_data: {test_count}")
    print(f"Total number of images: {train_val_count + test_count}")

# Call the function with your paths
split_data(data_dir, split_folder)
# Out:
# Split folders already exist. Skipping data split.

# %%
import os
import shutil
import random
import tensorflow as tf
# Define image parameters

# Define data augmentation parameters
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.10+.03,  # 10% of the data will be used for validation
)

train_generator = datagen.flow_from_directory(
    train_val_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='categorical',  # Update for multi-class classification
    subset='training'  # specify that this generator will be used for training data
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)


validation_generator = datagen.flow_from_directory(
    train_val_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='categorical',  # Update for multi-class classification
    subset='validation'  # specify that this generator will be used for validation data
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='categorical'  # Update for multi-class classification
)
# Out:
# Found 3009 images belonging to 2 classes.
# Found 448 images belonging to 2 classes.
# Found 386 images belonging to 2 classes.

# %%
images, labels = next(train_generator)

# Plot four random images from the batch
fig, axes = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    # Generate a random index
    random_index = np.random.randint(0, batch_size)
    
    # Plot the image
    axes[i].imshow(images[random_index])
    
    # Get the corresponding label
    label = labels[random_index]
    
    # Set the title as the class name
    class_name = train_generator.class_indices
    axes[i].set_title(list(class_name.keys())[np.argmax(label)])

plt.show()

# %% [markdown]
# # Building model

# %%
from tensorflow.keras.applications import EfficientNetV2B0,ResNet50,InceptionV3,NASNetMobile,EfficientNetV2L

model= InceptionV3(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
                
                 )

# Here we freeze the last 4 layers 
# Layers are set to trainable as True by default
for layer in model.layers:
    layer.trainable = False
    
# Let's print our layers 
for (i,layer) in enumerate(model.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 BatchNormalization False
# 3 Activation False
# 4 Conv2D False
# 5 BatchNormalization False
# 6 Activation False
# 7 Conv2D False
# 8 BatchNormalization False
# 9 Activation False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 BatchNormalization False
# 13 Activation False
# 14 Conv2D False
# 15 BatchNormalization False
# 16 Activation False
# 17 MaxPooling2D False
# 18 Conv2D False
# 19 BatchNormalization False
# 20 Activation False
# 21 Conv2D False
# 22 Conv2D False
# 23 BatchNormalization False
# 24 BatchNormalization False
# 25 Activation False
# 26 Activation False
# 27 AveragePooling2D False
# 28 Conv2D False
# 29 Conv2D False
# 30 Conv2D False
# 31 Conv2D False
# 32 BatchNormalization False
# 33 BatchNormalization False
# 34 BatchNormalization False
# 35 BatchNormalization False
# 36 Activation False
# 37 Activation False
# 38 Activation False
# 39 Activation False
# 40 Concatenate False
# 41 Conv2D False
# 42 BatchNormalization False
# 43 Activation False
# 44 Conv2D False
# 45 Conv2D False
# 46 BatchNormalization False
# 47 BatchNormalization False
# 48 Activation False
# 49 Activation False
# 50 AveragePooling2D False
# 51 Conv2D False
# 52 Conv2D False
# 53 Conv2D False
# 54 Conv2D False
# 55 BatchNormalization False
# 56 BatchNormalization False
# 57 BatchNormalization False
# 58 BatchNormalization False
# 59 Activation False
# 60 Activation False
# 61 Activation False
# 62 Activation False
# 63 Concatenate False
# 64 Conv2D False
# 65 BatchNormalization False
# 66 Activation False
# 67 Conv2D False
# 68 Conv2D False
# 69 BatchNormalization False
# 70 BatchNormalization False
# 71 Activation False
# 72 Activation False
# 73 AveragePooling2D False
# 74 Conv2D False
# 75 Conv2D False
# 76 Conv2D False
# 77 Conv2D False
# 78 BatchNormalization False
# 79 BatchNormalization False
# 80 BatchNormalization False
# 81 BatchNormalization False
# 82 Activation False
# 83 Activation False
# 84 Activation False
# 85 Activation False
# 86 Concatenate False
# 87 Conv2D False
# 88 BatchNormalization False
# 89 Activation False
# 90 Conv2D False
# 91 BatchNormalization False
# 92 Activation False
# 93 Conv2D False
# 94 Conv2D False
# 95 BatchNormalization False
# 96 BatchNormalization False
# 97 Activation False
# 98 Activation False
# 99 MaxPooling2D False
# 100 Concatenate False
# 101 Conv2D False
# 102 BatchNormalization False
# 103 Activation False
# 104 Conv2D False
# 105 BatchNormalization False
# 106 Activation False
# 107 Conv2D False
# 108 Conv2D False
# 109 BatchNormalization False
# 110 BatchNormalization False
# 111 Activation False
# 112 Activation False
# 113 Conv2D False
# 114 Conv2D False
# 115 BatchNormalization False
# 116 BatchNormalization False
# 117 Activation False
# 118 Activation False
# 119 AveragePooling2D False
# 120 Conv2D False
# 121 Conv2D False
# 122 Conv2D False
# 123 Conv2D False
# 124 BatchNormalization False
# 125 BatchNormalization False
# 126 BatchNormalization False
# 127 BatchNormalization False
# 128 Activation False
# 129 Activation False
# 130 Activation False
# 131 Activation False
# 132 Concatenate False
# 133 Conv2D False
# 134 BatchNormalization False
# 135 Activation False
# 136 Conv2D False
# 137 BatchNormalization False
# 138 Activation False
# 139 Conv2D False
# 140 Conv2D False
# 141 BatchNormalization False
# 142 BatchNormalization False
# 143 Activation False
# 144 Activation False
# 145 Conv2D False
# 146 Conv2D False
# 147 BatchNormalization False
# 148 BatchNormalization False
# 149 Activation False
# 150 Activation False
# 151 AveragePooling2D False
# 152 Conv2D False
# 153 Conv2D False
# 154 Conv2D False
# 155 Conv2D False
# 156 BatchNormalization False
# 157 BatchNormalization False
# 158 BatchNormalization False
# 159 BatchNormalization False
# 160 Activation False
# 161 Activation False
# 162 Activation False
# 163 Activation False
# 164 Concatenate False
# 165 Conv2D False
# 166 BatchNormalization False
# 167 Activation False
# 168 Conv2D False
# 169 BatchNormalization False
# 170 Activation False
# 171 Conv2D False
# 172 Conv2D False
# 173 BatchNormalization False
# 174 BatchNormalization False
# 175 Activation False
# 176 Activation False
# 177 Conv2D False
# 178 Conv2D False
# 179 BatchNormalization False
# 180 BatchNormalization False
# 181 Activation False
# 182 Activation False
# 183 AveragePooling2D False
# 184 Conv2D False
# 185 Conv2D False
# 186 Conv2D False
# 187 Conv2D False
# 188 BatchNormalization False
# 189 BatchNormalization False
# 190 BatchNormalization False
# 191 BatchNormalization False
# 192 Activation False
# 193 Activation False
# 194 Activation False
# 195 Activation False
# 196 Concatenate False
# 197 Conv2D False
# 198 BatchNormalization False
# 199 Activation False
# 200 Conv2D False
# 201 BatchNormalization False
# 202 Activation False
# 203 Conv2D False
# 204 Conv2D False
# 205 BatchNormalization False
# 206 BatchNormalization False
# 207 Activation False
# 208 Activation False
# 209 Conv2D False
# 210 Conv2D False
# 211 BatchNormalization False
# 212 BatchNormalization False
# 213 Activation False
# 214 Activation False
# 215 AveragePooling2D False
# 216 Conv2D False
# 217 Conv2D False
# 218 Conv2D False
# 219 Conv2D False
# 220 BatchNormalization False
# 221 BatchNormalization False
# 222 BatchNormalization False
# 223 BatchNormalization False
# 224 Activation False
# 225 Activation False
# 226 Activation False
# 227 Activation False
# 228 Concatenate False
# 229 Conv2D False
# 230 BatchNormalization False
# 231 Activation False
# 232 Conv2D False
# 233 BatchNormalization False
# 234 Activation False
# 235 Conv2D False
# 236 Conv2D False
# 237 BatchNormalization False
# 238 BatchNormalization False
# 239 Activation False
# 240 Activation False
# 241 Conv2D False
# 242 Conv2D False
# 243 BatchNormalization False
# 244 BatchNormalization False
# 245 Activation False
# 246 Activation False
# 247 MaxPooling2D False
# 248 Concatenate False
# 249 Conv2D False
# 250 BatchNormalization False
# 251 Activation False
# 252 Conv2D False
# 253 Conv2D False
# 254 BatchNormalization False
# 255 BatchNormalization False
# 256 Activation False
# 257 Activation False
# 258 Conv2D False
# 259 Conv2D False
# 260 Conv2D False
# 261 Conv2D False
# 262 AveragePooling2D False
# 263 Conv2D False
# 264 BatchNormalization False
# 265 BatchNormalization False
# 266 BatchNormalization False
# 267 BatchNormalization False
# 268 Conv2D False
# 269 BatchNormalization False
# 270 Activation False
# 271 Activation False
# 272 Activation False
# 273 Activation False
# 274 BatchNormalization False
# 275 Activation False
# 276 Concatenate False
# 277 Concatenate False
# 278 Activation False
# 279 Concatenate False
# 280 Conv2D False
# 281 BatchNormalization False
# 282 Activation False
# 283 Conv2D False
# 284 Conv2D False
# 285 BatchNormalization False
# 286 BatchNormalization False
# 287 Activation False
# 288 Activation False
# 289 Conv2D False
# 290 Conv2D False
# 291 Conv2D False
# 292 Conv2D False
# 293 AveragePooling2D False
# 294 Conv2D False
# 295 BatchNormalization False
# 296 BatchNormalization False
# 297 BatchNormalization False
# 298 BatchNormalization False
# 299 Conv2D False
# 300 BatchNormalization False
# 301 Activation False
# 302 Activation False
# 303 Activation False
# 304 Activation False
# 305 BatchNormalization False
# 306 Activation False
# 307 Concatenate False
# 308 Concatenate False
# 309 Activation False
# 310 Concatenate False

# %% [markdown]
# **Fine Tuning**

# %%
for layer in model.layers[:261]:
   layer.trainable = False
for layer in model.layers[261:]:
   layer.trainable = True

print('Last block of the conv_base is now trainable')


for i, layer in enumerate(model.layers):
   print(i, layer.name, layer.trainable)
# Out:
# Last block of the conv_base is now trainable
# 0 input_1 False
# 1 conv2d False
# 2 batch_normalization False
# 3 activation False
# 4 conv2d_1 False
# 5 batch_normalization_1 False
# 6 activation_1 False
# 7 conv2d_2 False
# 8 batch_normalization_2 False
# 9 activation_2 False
# 10 max_pooling2d False
# 11 conv2d_3 False
# 12 batch_normalization_3 False
# 13 activation_3 False
# 14 conv2d_4 False
# 15 batch_normalization_4 False
# 16 activation_4 False
# 17 max_pooling2d_1 False
# 18 conv2d_8 False
# 19 batch_normalization_8 False
# 20 activation_8 False
# 21 conv2d_6 False
# 22 conv2d_9 False
# 23 batch_normalization_6 False
# 24 batch_normalization_9 False
# 25 activation_6 False
# 26 activation_9 False
# 27 average_pooling2d False
# 28 conv2d_5 False
# 29 conv2d_7 False
# 30 conv2d_10 False
# 31 conv2d_11 False
# 32 batch_normalization_5 False
# 33 batch_normalization_7 False
# 34 batch_normalization_10 False
# 35 batch_normalization_11 False
# 36 activation_5 False
# 37 activation_7 False
# 38 activation_10 False
# 39 activation_11 False
# 40 mixed0 False
# 41 conv2d_15 False
# 42 batch_normalization_15 False
# 43 activation_15 False
# 44 conv2d_13 False
# 45 conv2d_16 False
# 46 batch_normalization_13 False
# 47 batch_normalization_16 False
# 48 activation_13 False
# 49 activation_16 False
# 50 average_pooling2d_1 False
# 51 conv2d_12 False
# 52 conv2d_14 False
# 53 conv2d_17 False
# 54 conv2d_18 False
# 55 batch_normalization_12 False
# 56 batch_normalization_14 False
# 57 batch_normalization_17 False
# 58 batch_normalization_18 False
# 59 activation_12 False
# 60 activation_14 False
# 61 activation_17 False
# 62 activation_18 False
# 63 mixed1 False
# 64 conv2d_22 False
# 65 batch_normalization_22 False
# 66 activation_22 False
# 67 conv2d_20 False
# 68 conv2d_23 False
# 69 batch_normalization_20 False
# 70 batch_normalization_23 False
# 71 activation_20 False
# 72 activation_23 False
# 73 average_pooling2d_2 False
# 74 conv2d_19 False
# 75 conv2d_21 False
# 76 conv2d_24 False
# 77 conv2d_25 False
# 78 batch_normalization_19 False
# 79 batch_normalization_21 False
# 80 batch_normalization_24 False
# 81 batch_normalization_25 False
# 82 activation_19 False
# 83 activation_21 False
# 84 activation_24 False
# 85 activation_25 False
# 86 mixed2 False
# 87 conv2d_27 False
# 88 batch_normalization_27 False
# 89 activation_27 False
# 90 conv2d_28 False
# 91 batch_normalization_28 False
# 92 activation_28 False
# 93 conv2d_26 False
# 94 conv2d_29 False
# 95 batch_normalization_26 False
# 96 batch_normalization_29 False
# 97 activation_26 False
# 98 activation_29 False
# 99 max_pooling2d_2 False
# 100 mixed3 False
# 101 conv2d_34 False
# 102 batch_normalization_34 False
# 103 activation_34 False
# 104 conv2d_35 False
# 105 batch_normalization_35 False
# 106 activation_35 False
# 107 conv2d_31 False
# 108 conv2d_36 False
# 109 batch_normalization_31 False
# 110 batch_normalization_36 False
# 111 activation_31 False
# 112 activation_36 False
# 113 conv2d_32 False
# 114 conv2d_37 False
# 115 batch_normalization_32 False
# 116 batch_normalization_37 False
# 117 activation_32 False
# 118 activation_37 False
# 119 average_pooling2d_3 False
# 120 conv2d_30 False
# 121 conv2d_33 False
# 122 conv2d_38 False
# 123 conv2d_39 False
# 124 batch_normalization_30 False
# 125 batch_normalization_33 False
# 126 batch_normalization_38 False
# 127 batch_normalization_39 False
# 128 activation_30 False
# 129 activation_33 False
# 130 activation_38 False
# 131 activation_39 False
# 132 mixed4 False
# 133 conv2d_44 False
# 134 batch_normalization_44 False
# 135 activation_44 False
# 136 conv2d_45 False
# 137 batch_normalization_45 False
# 138 activation_45 False
# 139 conv2d_41 False
# 140 conv2d_46 False
# 141 batch_normalization_41 False
# 142 batch_normalization_46 False
# 143 activation_41 False
# 144 activation_46 False
# 145 conv2d_42 False
# 146 conv2d_47 False
# 147 batch_normalization_42 False
# 148 batch_normalization_47 False
# 149 activation_42 False
# 150 activation_47 False
# 151 average_pooling2d_4 False
# 152 conv2d_40 False
# 153 conv2d_43 False
# 154 conv2d_48 False
# 155 conv2d_49 False
# 156 batch_normalization_40 False
# 157 batch_normalization_43 False
# 158 batch_normalization_48 False
# 159 batch_normalization_49 False
# 160 activation_40 False
# 161 activation_43 False
# 162 activation_48 False
# 163 activation_49 False
# 164 mixed5 False
# 165 conv2d_54 False
# 166 batch_normalization_54 False
# 167 activation_54 False
# 168 conv2d_55 False
# 169 batch_normalization_55 False
# 170 activation_55 False
# 171 conv2d_51 False
# 172 conv2d_56 False
# 173 batch_normalization_51 False
# 174 batch_normalization_56 False
# 175 activation_51 False
# 176 activation_56 False
# 177 conv2d_52 False
# 178 conv2d_57 False
# 179 batch_normalization_52 False
# 180 batch_normalization_57 False
# 181 activation_52 False
# 182 activation_57 False
# 183 average_pooling2d_5 False
# 184 conv2d_50 False
# 185 conv2d_53 False
# 186 conv2d_58 False
# 187 conv2d_59 False
# 188 batch_normalization_50 False
# 189 batch_normalization_53 False
# 190 batch_normalization_58 False
# 191 batch_normalization_59 False
# 192 activation_50 False
# 193 activation_53 False
# 194 activation_58 False
# 195 activation_59 False
# 196 mixed6 False
# 197 conv2d_64 False
# 198 batch_normalization_64 False
# 199 activation_64 False
# 200 conv2d_65 False
# 201 batch_normalization_65 False
# 202 activation_65 False
# 203 conv2d_61 False
# 204 conv2d_66 False
# 205 batch_normalization_61 False
# 206 batch_normalization_66 False
# 207 activation_61 False
# 208 activation_66 False
# 209 conv2d_62 False
# 210 conv2d_67 False
# 211 batch_normalization_62 False
# 212 batch_normalization_67 False
# 213 activation_62 False
# 214 activation_67 False
# 215 average_pooling2d_6 False
# 216 conv2d_60 False
# 217 conv2d_63 False
# 218 conv2d_68 False
# 219 conv2d_69 False
# 220 batch_normalization_60 False
# 221 batch_normalization_63 False
# 222 batch_normalization_68 False
# 223 batch_normalization_69 False
# 224 activation_60 False
# 225 activation_63 False
# 226 activation_68 False
# 227 activation_69 False
# 228 mixed7 False
# 229 conv2d_72 False
# 230 batch_normalization_72 False
# 231 activation_72 False
# 232 conv2d_73 False
# 233 batch_normalization_73 False
# 234 activation_73 False
# 235 conv2d_70 False
# 236 conv2d_74 False
# 237 batch_normalization_70 False
# 238 batch_normalization_74 False
# 239 activation_70 False
# 240 activation_74 False
# 241 conv2d_71 False
# 242 conv2d_75 False
# 243 batch_normalization_71 False
# 244 batch_normalization_75 False
# 245 activation_71 False
# 246 activation_75 False
# 247 max_pooling2d_3 False
# 248 mixed8 False
# 249 conv2d_80 False
# 250 batch_normalization_80 False
# 251 activation_80 False
# 252 conv2d_77 False
# 253 conv2d_81 False
# 254 batch_normalization_77 False
# 255 batch_normalization_81 False
# 256 activation_77 False
# 257 activation_81 False
# 258 conv2d_78 False
# 259 conv2d_79 False
# 260 conv2d_82 False
# 261 conv2d_83 True
# 262 average_pooling2d_7 True
# 263 conv2d_76 True
# 264 batch_normalization_78 True
# 265 batch_normalization_79 True
# 266 batch_normalization_82 True
# 267 batch_normalization_83 True
# 268 conv2d_84 True
# 269 batch_normalization_76 True
# 270 activation_78 True
# 271 activation_79 True
# 272 activation_82 True
# 273 activation_83 True
# 274 batch_normalization_84 True
# 275 activation_76 True
# 276 mixed9_0 True
# 277 concatenate True
# 278 activation_84 True
# 279 mixed9 True
# 280 conv2d_89 True
# 281 batch_normalization_89 True
# 282 activation_89 True
# 283 conv2d_86 True
# 284 conv2d_90 True
# 285 batch_normalization_86 True
# 286 batch_normalization_90 True
# 287 activation_86 True
# 288 activation_90 True
# 289 conv2d_87 True
# 290 conv2d_88 True
# 291 conv2d_91 True
# 292 conv2d_92 True
# 293 average_pooling2d_8 True
# 294 conv2d_85 True
# 295 batch_normalization_87 True
# 296 batch_normalization_88 True
# 297 batch_normalization_91 True
# 298 batch_normalization_92 True
# 299 conv2d_93 True
# 300 batch_normalization_85 True
# 301 activation_87 True
# 302 activation_88 True
# 303 activation_91 True
# 304 activation_92 True
# 305 batch_normalization_93 True
# 306 activation_85 True
# 307 mixed9_1 True
# 308 concatenate_1 True
# 309 activation_93 True
# 310 mixed10 True

# %%
def lw(bottom_model, num_classes):
    """creates the top or head of the model that will be 
    placed on top of the bottom layers"""

    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation='relu',kernel_regularizer=l2(0.01))(top_model)  # Adding L2 regularization
    # top_model = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(top_model)  # You can add regularization to more layers if needed
    # top_model = BatchNormalization()(top_model)
    #top_model = Dropout(0.6)(top_model) 
    #top_model = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(top_model)  # Adding L2 regularization
    # top_model = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(top_model)  # You can add regularization to more layers if needed
    # top_model = BatchNormalization()(top_model)
    top_model = Dropout(0.5)(top_model) 
    top_model = Dense(num_classes, activation='softmax')(top_model)
    return top_model

# %%
from keras.models import Model
FC_Head = lw(model, NUM_CLASSES)
model = Model(inputs = model.input, outputs = FC_Head)
#print(model.summary())

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import LearningRateScheduler


def scheduler(epoch, lr):
     if epoch < 5:
         return .0008
     else:
        return .0008

lr_scheduler = LearningRateScheduler(scheduler)

# %%
if not os.path.exists("Results"):
    os.makedirs("Results")
if not os.path.exists("Model"):
    os.makedirs("Model") 
csv_logger_path = os.path.join("Results", f"{model_name}_results.csv")
model_checkpoint_path = os.path.join("Model", f"{model_name}_Model.hdf5")

# %% [markdown]
# **CheckPoints**

# %%
csv_logger = CSVLogger(csv_logger_path)
early_stopping = EarlyStopping(monitor='val_loss', patience=patience)
check = ModelCheckpoint(model_checkpoint_path, verbose=1, save_best_only=True)
progbar_logger = ProgbarLogger()

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])
history = model.fit(train_generator,
                    epochs=EPOCHS, 
                    batch_size=batch_size,
                    validation_data=validation_generator,
                    verbose = 1,
                    callbacks = [early_stopping,lr_scheduler,check,csv_logger],
                    initial_epoch=0)
# Out:
# Epoch 1/25
# 301/301 [==============================] - ETA: 0s - loss: 1.7474 - accuracy: 0.9904
# Epoch 1: val_loss improved from inf to 0.02861, saving model to Model\convenext_Model.hdf5
# 301/301 [==============================] - 54s 150ms/step - loss: 1.7474 - accuracy: 0.9904 - val_loss: 0.0286 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 2/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.0995 - accuracy: 0.9950
# Epoch 2: val_loss did not improve from 0.02861
# 301/301 [==============================] - 15s 49ms/step - loss: 0.0993 - accuracy: 0.9950 - val_loss: 0.0318 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 3/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9983
# Epoch 3: val_loss improved from 0.02861 to 0.00545, saving model to Model\convenext_Model.hdf5
# 301/301 [==============================] - 15s 50ms/step - loss: 0.0217 - accuracy: 0.9983 - val_loss: 0.0055 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 4/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9993
# Epoch 4: val_loss did not improve from 0.00545
# 301/301 [==============================] - 15s 49ms/step - loss: 0.0308 - accuracy: 0.9993 - val_loss: 0.0738 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 5/25
# 301/301 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9987
# Epoch 5: val_loss improved from 0.00545 to 0.00368, saving model to Model\convenext_Model.hdf5
# 301/301 [==============================] - 15s 50ms/step - loss: 0.0289 - accuracy: 0.9987 - val_loss: 0.0037 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 6/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 6: val_loss improved from 0.00368 to 0.00259, saving model to Model\convenext_Model.hdf5
# 301/301 [==============================] - 15s 51ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 7/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.0924 - accuracy: 0.9953
# Epoch 7: val_loss did not improve from 0.00259
# 301/301 [==============================] - 15s 49ms/step - loss: 0.0930 - accuracy: 0.9953 - val_loss: 41.5945 - val_accuracy: 0.4643 - lr: 8.0000e-04
# Epoch 8/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.4143 - accuracy: 0.9897
# Epoch 8: val_loss did not improve from 0.00259
# 301/301 [==============================] - 15s 49ms/step - loss: 0.4134 - accuracy: 0.9897 - val_loss: 0.1488 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 9/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9943
# Epoch 9: val_loss did not improve from 0.00259
# 301/301 [==============================] - 15s 49ms/step - loss: 0.0826 - accuracy: 0.9944 - val_loss: 0.0307 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 10/25
# 300/301 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9993
# Epoch 10: val_loss did not improve from 0.00259
# 301/301 [==============================] - 15s 49ms/step - loss: 0.0197 - accuracy: 0.9993 - val_loss: 0.0075 - val_accuracy: 1.0000 - lr: 8.0000e-04
# Epoch 11/25
# 301/301 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9973
# Epoch 11: val_loss did not improve from 0.00259
# 301/301 [==============================] - 15s 50ms/step - loss: 0.0597 - accuracy: 0.9973 - val_loss: 0.0260 - val_accuracy: 1.0000 - lr: 8.0000e-04

# %% [markdown]
# **saving models**

# %%
import pickle

pickle_path_json = os.path.join("Results", f"{model_name}_model_architecture.json")
pickle_model_path = os.path.join("Model", f"{model_name}_model_pickle.pkl")

# Save model architecture to JSON (only needed once)
model_architecture = model.to_json()
with open(pickle_path_json, 'w') as f:
    f.write(model_architecture)

# Save model weights using pickle
with open(pickle_model_path, 'wb') as f:
    pickle.dump(model, f)
# Out:
# INFO:tensorflow:Assets written to: ram://796b3392-a39d-4e1f-8c22-cb724d0e74dd/assets

# %%
model.save(f'{model_name}_.h5')

# %%
model = tf.keras.models.load_model(f'{model_name}_.h5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

# %%
plt.figure(figsize=(7, 4))
plt.plot((epochs ), history.history['accuracy'], label='Training Accuracy')
plt.plot((epochs ), history.history['val_accuracy'], label='Validation Accuracy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.plot(epochs, history.history['loss'], label='Training Loss')
plt.plot(epochs, history.history['val_loss'], label='Validation Loss')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming the following are defined:
# epochs: list of epoch numbers (e.g., [1, 2, 3, ..., num_epochs])
# history: training history object containing 'accuracy', 'val_accuracy', 'loss', and 'val_loss' metrics

fig, ax1 = plt.subplots(figsize=(7, 4))

# Plot Training and Validation Accuracy
ax1.plot(epochs, history.history['accuracy'], label='Training Accuracy', color='blue')
ax1.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy', color='orange')

# Set y-axis label and limits for accuracy
ax1.set_ylabel('Accuracy/Loss', color='blue')
ax1.set_xlabel('Epoch', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim([0, 1])  # Limit y-axis for accuracy between 0 and 1

# Create a second y-axis for loss
ax2 = ax1.twinx()
ax2.plot(epochs, history.history['loss'], label='Training Loss', color='violet')
ax2.plot(epochs, history.history['val_loss'], label='Validation Loss', color='red')

# Hide y-axis ticks and labels for loss
ax2.set_yticks([])  # Remove y-axis ticks
ax2.set_ylabel('')  # Set empty string to hide the label

# Add grid, legends, title, and x-axis label
ax1.grid(True, linestyle='--', alpha=0.7)

# Combine legends for accuracy and loss in the middle right
handles, labels = [], []
for ax in [ax1, ax2]:
    h, l = ax.get_legend_handles_labels()
    handles.extend(h)
    labels.extend(l)

# Adjust legend position to be slightly left of center right
fig.legend(handles, labels, loc='center right', bbox_to_anchor=(0.85, 0.5))

plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')

# Show plot
plt.tight_layout()
plt.show()

# %%
score = model.evaluate(test_generator ,verbose=1)
print('Test Loss:', score[0])
print('Test accuracy:', score[1]*100)
# Out:
# 39/39 [==============================] - 5s 97ms/step - loss: 0.0260 - accuracy: 1.0000
# Test Loss: 0.026018468663096428
# Test accuracy: 100.0

# %%
import numpy as np
from sklearn.metrics import classification_report,confusion_matrix

# Initialize empty lists to store true and predicted labels
y_true_all = []
y_pred_all = []

# Loop through all batches in the validation generator
for i in range(len(test_generator)):
    # Get the next batch of data
    x_val, y_val = test_generator[i]
    
    # Predict labels for the batch
    y_pred_prob = model.predict(x_val)
    y_pred = np.argmax(y_pred_prob, axis=1)
    
    # Append true and predicted labels to the lists
    y_true_all.extend(np.argmax(y_val, axis=1))
    y_pred_all.extend(y_pred)

# Convert lists to numpy arrays
y_true_all = np.array(y_true_all)
y_pred_all = np.array(y_pred_all)

# Get class labels
class_labels = list(validation_generator.class_indices.keys())

# Generate classification report
report = classification_report(y_true_all, y_pred_all, target_names=class_labels, zero_division=1,digits=4)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     infected     1.0000    1.0000    1.0000       157
#  notinfected     1.0000    1.0000    1.0000       229
#
#     accuracy                         1.0000       386
#    macro avg     1.0000    1.0000    1.0000       386
# weighted avg     1.0000    1.0000    1.0000       386

# %%
pip install numpy --upgrade
# Out:
# Requirement already satisfied: numpy in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (1.21.1)
# Collecting numpy
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.1
#     Uninstalling numpy-1.21.1:
#       Successfully uninstalled numpy-1.21.1
# Successfully installed numpy-1.24.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Maksura Nuha\anaconda3\envs\tf-gpu-env\Lib\site-packages\~-.py'.
#   You can safely remove it manually.

# %%
pip install pandas scikit-image seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (2.0.3)
# Requirement already satisfied: scikit-image in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (0.21.0)
# Requirement already satisfied: seaborn in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: scipy>=1.8 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (10.3.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (23.2)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\maksura nuha\anaconda3\envs\tf-gpu-env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy==1.21.1
# Out:
# Collecting numpy==1.21.1
#   Using cached numpy-1.21.1-cp38-cp38-win_amd64.whl.metadata (2.0 kB)
# Using cached numpy-1.21.1-cp38-cp38-win_amd64.whl (14.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed numpy-1.21.1
# Note: you may need to restart the kernel to use updated packages.

# %%
cm = confusion_matrix(y_true_all, y_pred_all)
import seaborn as sns
# Get class labels
class_labels = list(validation_generator.class_indices.keys())
#sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=class_labels, yticklabels=class_labels)
# Plot confusion matrix
plt.figure(figsize=(15, 8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Calculate confusion matrix
cm = confusion_matrix(y_true_all, y_pred_all)

# Get class labels
class_labels = list(validation_generator.class_indices.keys())

# Plot confusion matrix with a colorful palette
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='viridis', fmt='g', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
predicted_vals = model.predict(test_generator, steps = len(test_generator))
predicted_vals.shape  # number of test samples x number of classes to predict
# Out:
# (386, 2)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
labels = list(test_generator.class_indices.keys())

def get_roc_curve(labels, predicted_vals, generator):
    auc_roc_vals = []
    for i in range(len(labels)):
        try:
            gt = generator.labels[:, i]
            pred = predicted_vals[:, i]
            auc_roc = roc_auc_score(gt, pred)
            auc_roc_vals.append(auc_roc)
            fpr_rf, tpr_rf, _ = roc_curve(gt, pred)
            plt.figure(1, figsize=(10, 10))
            plt.plot([0, 1], [0, 1], 'k--')
            plt.plot(fpr_rf, tpr_rf,
                     label=labels[i] + " (" + str(round(auc_roc, 3)) + ")")
            plt.xlabel('False positive rate')
            plt.ylabel('True positive rate')
            plt.title('ROC curve')
            plt.legend(loc='best')
        except:
            print(
                f"Error in generating ROC curve for {labels[i]}. "
                f"Dataset lacks enough examples."
            )
    plt.savefig('ROC.png')
    plt.show()
    return auc_roc_vals
auc_rocs = get_roc_curve(labels, predicted_vals, test_generator)
# Out:
# Error in generating ROC curve for infected. Dataset lacks enough examples.
# Error in generating ROC curve for notinfected. Dataset lacks enough examples.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics

# Assuming the following are defined:
# test_generator: the data generator for test data
# model: the trained model

# Predict probabilities for the test data
y_proba = model.predict(test_generator)
y_true = test_generator.classes  # True labels

# Get the class labels
labels = list(test_generator.class_indices.keys())

# Initialize dictionary to store AUC values for each class
roc_auc_ovr = {}

# Convert the true labels to one-hot encoding
y_true_one_hot = np.eye(len(labels))[y_true]

# Plot the ROC Curves One vs Rest
for i in range(len(labels)):
    # Get the class name
    c = labels[i]

    # Compute ROC curve and AUC for the current class
    fpr, tpr, _ = metrics.roc_curve(y_true_one_hot[:, i], y_proba[:, i])
    roc_auc = metrics.auc(fpr, tpr)
    roc_auc_ovr[c] = roc_auc

    # Plot the ROC curve
    plt.plot(fpr, tpr, label=f'{c} (AUC={roc_auc:.4f})')

# Plot diagonal line for reference
plt.plot([0, 1], [0, 1], color='green', linestyle='dashed')

# Add labels and legend
plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.legend(loc="lower right")
plt.title('ROC Curves for Multi-Class Classification')
plt.show()

# Print overall AUC scores for each class
for class_name, auc_score in roc_auc_ovr.items():
    print(f'{class_name}: ROC AUC = {auc_score:.4f}')
# Out:
# infected: ROC AUC = 0.4883
# notinfected: ROC AUC = 0.4861

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# Assuming the following are defined:
# test_generator: the data generator for test data
# model: the trained model

# Predict probabilities for the test data
y_proba = model.predict(test_generator)
y_true = test_generator.classes  # True labels

# Get the class labels
labels = list(test_generator.class_indices.keys())

# Initialize dictionary to store specificity values for each class
specificity_ovr = {}

# Function to calculate specificity from confusion matrix
def calculate_specificity(cm):
    # For binary classification, cm[0,0] is TN, cm[0,1] is FP, cm[1,0] is FN, cm[1,1] is TP
    # For multi-class, we use the confusion matrix in a specific way to get TN and FP for each class
    # Here, we calculate specificity for the negative class (index 0 in our case)
    true_negative = cm[0, 0]  # TN
    false_positive = cm[0, 1]  # FP
    specificity = true_negative / (true_negative + false_positive + 1e-10)  # Adding a small epsilon to avoid division by zero
    return specificity

# Compute confusion matrix and specificity for each class
for i in range(len(labels)):
    # Get the class name
    c = labels[i]

    # Get predictions and true labels for the current class
    y_pred_class = np.argmax(y_proba, axis=1)
    y_true_class = np.where(y_true == i, 1, 0)

    # Compute confusion matrix
    cm = confusion_matrix(y_true_class, y_pred_class)

    # Calculate specificity for the current class
    specificity = calculate_specificity(cm)

    # Store the specificity value
    specificity_ovr[c] = specificity

# Print specificity scores for each class
for class_name, specificity in specificity_ovr.items():
    print(f'{class_name}: Specificity = {specificity:.4f}')
# Out:
# infected: Specificity = 0.3974
# notinfected: Specificity = 0.4204
